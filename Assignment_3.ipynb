# %%
# split the column city

# %%
from IPython.display import Image
Image(filename='D:/Power BI and Tableau Ineuron/Assignment_3/ss1.png', width=1400, height=1400)

# %%
# First name from employee name

# %%
Image(filename='D:/Power BI and Tableau Ineuron/Assignment_3/ss2.png', width=1400, height=1400)

# %%
# extract year and number of days of month from joining date

# %%
Image(filename='D:/Power BI and Tableau Ineuron/Assignment_3/ss3.png', width=1400, height=1400)

# %%
# compare the salaries state wise
# Chandigarh has lowest payout

# %%
Image(filename='D:/Power BI and Tableau Ineuron/Assignment_3/ss4.png', width=1400, height=1400)
