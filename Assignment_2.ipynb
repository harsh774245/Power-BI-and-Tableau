# %%
# Data is connected
# Removed all blank rows
# Updated column headers

# %%
from IPython.display import Image
Image(filename='D:/Power BI and Tableau Ineuron/Assignment_2/ss1.png', width=1400, height=1400)

# %%
# text table

# %%
Image(filename='D:/Power BI and Tableau Ineuron/Assignment_2/ss2.png', width=1400, height=1400)

# %%
# line and clustered column chart
# A slicer was used to identify the region with the highest sales in Technology
# New york has the highest sales

# %%
Image(filename='D:/Power BI and Tableau Ineuron/Assignment_2/ss3.png', width=1400, height=1400)

# %%
# Donut chart before using the slicer for region

# %%
Image(filename='D:/Power BI and Tableau Ineuron/Assignment_2/ss4.png', width=1400, height=1400)

# %%
# Donut chart after using the slicer for region

# %%
Image(filename='D:/Power BI and Tableau Ineuron/Assignment_2/ss5.png', width=1400, height=1400)
