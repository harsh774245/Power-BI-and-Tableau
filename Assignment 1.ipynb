# %%
# Screenshot of report view page

# %%
from IPython.display import Image
Image(filename='D:/Power BI and Tableau Ineuron/Assignment_1/task1.png', width=1000, height=1000)

# %%
# Report view

# %%
Image(filename='D:/Power BI and Tableau Ineuron/Assignment_1/report_view.png', width=1000, height=1000)

# %%
# Data view

# %%
Image(filename='D:/Power BI and Tableau Ineuron/Assignment_1/data_view.png', width=1000, height=1000)

# %%
# Model view

# %%
Image(filename='D:/Power BI and Tableau Ineuron/Assignment_1/model_view.png', width=1000, height=1000)

# %%
# Power query editor

# %%
Image(filename='D:/Power BI and Tableau Ineuron/Assignment_1/pqe.png', width=1000, height=1000)

# %%
# Advance Editor

# %%
Image(filename='D:/Power BI and Tableau Ineuron/Assignment_1/adv_editor.png', width=1000, height=1000)

# %% [markdown]
# Power BI Desktop Free
#
#
# Power BI Pro 660 INR monthly per user
#
#
# Power BI Premium 3,30,190 INR monthly price per dedicated cloud compute and storage resource with annual subscription
